# %%
#Import libary
import pandas as pd
bigdata = pd.read_csv('employee-compensation.csv')
bigdata.head()
# Out:
# /Users/devfx/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
# ...

# %%
#Import libary visualisasi data
import matplotlib.pyplot as plt
import numpy as np

# %%
#menentukan ukuran gambar/bingkai
plt.figure(figsize=(12,8))
#Menulis title bingkai
plt.title('Gaji Pegawai di Kota Fransisco Brazil', fontdict={'fontweight':'bold','fontsize':16})
#memanggil atribut salaries
plt.scatter(bigdata.index, bigdata['Salaries'])

#membuat label X dan Y
plt.xlabel('Pekerjaan')
plt.ylabel('Gaji')

plt.show()

# %%
#menentukan ukuran gambar/bingkai
plt.figure(figsize=(12,8))
#Menulis title bingkai
plt.title('Gaji Pegawai Lembur di kota Fransisco ', fontdict={'fontweight':'bold','fontsize':16})
#memanggil atribut salaries
plt.scatter(bigdata.index, bigdata['Overtime'])

#membuat label X dan Y
plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Lembur')

plt.show()

# %%
#menentukan ukuran gambar/bingkai
plt.figure(figsize=(12,8))
#Menulis title bingkai
plt.title('Gaji Tambahan Pegawai di kota Fransisco ', fontdict={'fontweight':'bold','fontsize':16})
#memanggil atribut salaries
plt.scatter(bigdata.index, bigdata['Other Salaries'])

#membuat label X dan Y
plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Tambahan')

plt.show()

# %%
#menentukan ukuran gambar/bingkai
plt.figure(figsize=(12,8))
#Menulis title bingkai
plt.title('Gaji Total Pegawai di kota Fransisco ', fontdict={'fontweight':'bold','fontsize':16})
#memanggil atribut salaries
plt.scatter(bigdata.index, bigdata['Total Salary'])

#membuat label X dan Y
plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Total')

plt.show()

# %%
#menentukan ukuran gambar/bingkai
plt.figure(figsize=(12,8))
#Menulis title bingkai
plt.title('Gaji Pegawai Pensiunan di kota Fransisco ', fontdict={'fontweight':'bold','fontsize':16})
#memanggil atribut salaries
plt.scatter(bigdata.index, bigdata['Retirement'])

#membuat label X dan Y
plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Pensiun')

plt.show()

# %%
#menentukan ukuran gambar/bingkai
plt.figure(figsize=(12,8))
#Menulis title bingkai
plt.title('Tunj ', fontdict={'fontweight':'bold','fontsize':16})
#memanggil atribut salaries
plt.scatter(bigdata.index, bigdata['Retirement'])

#membuat label X dan Y
plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Pensiun')

plt.show()

# %%
#Data Cleaning
import pandas as pd
bigdata = pd.read_csv('employee-compensation.csv')
bigdata.head()
# Out:
# /Users/devfx/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
# ...

# %%
#Memilih data gaji pegawai yang bukan bernilai 0
datapegawai = bigdata[bigdata.Salaries != 0]
#Membuat funsgi ABS 
salaries={}
for baris in datapegawai['Salaries']:
    if baris < 0 :
        salaries=abs(datapegawai['Salaries'])
overtime={}
for baris in datapegawai['Overtime']:
    if baris < 0 :
        overtime=abs(datapegawai['Overtime'])
other_salaries={}
for baris in datapegawai['Other Salaries']:
    if baris < 0 :
        other_salaries=abs(datapegawai['Other Salaries'])
total_salaries={}
for baris in datapegawai['Total Salary']:
    if baris < 0 :
        total_salaries=abs(datapegawai['Total Salary'])
retirement={}
for baris in datapegawai['Retirement']:
    if baris < 0 :
        retirement=abs(datapegawai['Retirement'])
health_and_dental={}
for baris in datapegawai['Health and Dental']:
    if baris < 0 :
        health_and_dental=abs(datapegawai['Health and Dental'])
other_benefit={}
for baris in datapegawai['Other Benefits']:
    if baris < 0 :
        other_benefit=abs(datapegawai['Other Benefits'])
total_benefit={}
for baris in datapegawai['Total Benefits']:
    if baris < 0 :
        total_benefit=abs(datapegawai['Total Benefits'])
total_compensation={}
for baris in datapegawai['Total Compensation']:
    if baris < 0 :
        total_compentation=abs(datapegawai['Total Compensation'])

# %%
#Membuat data Frame Baru
datasuci=pd.DataFrame({'salaries': salaries, 'overtime': overtime,'retirement':retirement,'other salaries': other_salaries,'total salary': total_salaries,'health and dental': health_and_dental,'other benefits': other_benefit,'total compensation': total_compensation})

# %%
datasuci.head()
# Out:
#    salaries  overtime  retirement  other salaries  total salary  \
# 0    674.28      0.00      130.91            5.76        680.04
# 1    674.28      0.00      130.91            5.76        680.04
# 2    674.28      0.00      130.91            5.76        680.04
# 3  47822.00      0.00     9986.92          264.00      48086.00
# 4  61089.35  39316.78    12385.79         6966.37     107372.50
#
#    health and dental  other benefits  total compensation
# 0               0.00           53.86                 NaN
# 1               0.00           53.86                 NaN
# 2               0.00           53.86                 NaN
# 3            6747.52         3898.79                 NaN
# 4            6606.96         1816.03                 NaN

# %%
bigdata.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
#   Union Code                           Union Job Family Code       Job Family  \
# 0        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# 1        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# ...

# %%
datanew=datapegawai.drop('Salaries',axis=1)
datanew=datanew.drop('Overtime',axis=1)
datanew=datanew.drop('Other Salaries',axis=1)
datanew=datanew.drop('Total Salary',axis=1)
datanew=datanew.drop('Retirement',axis=1)
datanew=datanew.drop('Health and Dental',axis=1)
datanew=datanew.drop('Other Benefits',axis=1)
datanew=datanew.drop('Total Benefits',axis=1)
datanew=datanew.drop('Total Compensation',axis=1)
datasuciterbaru=pd.concat([datanew, datasuci],axis=1)
datasuciterbaru.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
#   Union Code                           Union Job Family Code       Job Family  \
# 0        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# 1        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# ...

# %%
datasuci=datasuciterbaru.drop_duplicates(keep=False)

# %%
bytes_to_write = datasuci.to_csv('datasuci.csv')
