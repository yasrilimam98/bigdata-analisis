# %%
#Import libary
import pandas as pd
bigdata=pd.read_csv('employee-compensation.csv')
bigdata.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
#   Union Code                           Union Job Family Code       Job Family  \
# 0        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# 1        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# ...

# %%
#Import libary visualisasi data
import matplotlib.pyplot as plt
import numpy as np

#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Gaji Karyawan di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Salaries'])

plt.xlabel('Pekerjaan')
plt.ylabel('Gaji')

plt.savefig('Gaji Karyawan di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Gaji Lembur di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Overtime'])

plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Lembur')

plt.savefig('Gaji Lembur di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Gaji Tambahan di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Other Salaries'])

plt.xlabel('Pekerjaan')
plt.ylabel('Gaji Tambahan')

plt.savefig('Gaji Tambahan di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Total Gaji di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Total Salary'])

plt.xlabel('Pekerjaan')
plt.ylabel('Total Gaji')

plt.savefig('Total Gaji di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Besar Pensiunan di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Retirement'])

plt.xlabel('Pekerjaan')
plt.ylabel('Pensiunan')

plt.savefig('Besar Pensiunan di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Tunjangan Kesehatan dan Gigi di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Health and Dental'])

plt.xlabel('Pekerjaan')
plt.ylabel('Tunjangan Kesehatan dan Gigi')

plt.savefig('Tunjangan Kesehatan dan Gigi di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Besar Tunjangan Karyawan di Kota San Fransico', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Other Benefits'])

plt.xlabel('Pekerjaan')
plt.ylabel('Tunjangan Lainnya')

plt.savefig('Besar Tunjangan Karyawan di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Tunjangan Karyawan di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Total Benefits'])

plt.xlabel('Pekerjaan')
plt.ylabel('Tunjangan Karyawan')

plt.savefig('Tunjangan Karyawan di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Menentukan ukuran gambar
plt.figure(figsize=(12,8))
#Ploting
plt.title('Total Kompensasi Karyawan di Kota San Fransisco', fontdict={'fontweight':'bold', 'fontsize': 18})
#float64(data['Salaries'])
plt.scatter(data.index, data['Total Compensation'])

plt.xlabel('Pekerjaan')
plt.ylabel('Total Kompensasi')

plt.savefig('Total Kompensasi di Kota San Fransico.png', dpi=300)

plt.show()

# %%
#Data Cleaning
import pandas as pd
bigdatadata=pd.read_csv('employee-compensation.csv')
bigdata.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
#   Union Code                           Union Job Family Code       Job Family  \
# 0        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# 1        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# ...

# %%
#Memilih data gaji pokok yang bukan nol
datapegawai=bigdata[bigdata.Salaries != 0]
#Membuat data yang negatif menjadi positif
salaries={}
for baris in datapegawai['Salaries']:
    if baris < 0:
        salaries=abs(datapegawai['Salaries'])

overtime={}
for baris in datapegawai['Overtime']:
    if baris < 0:
        overtime=abs(datapegawai['Overtime'])

other_salaries={}
for baris in datapegawai['Other Salaries']:
    if baris < 0:
        other_salaries=abs(datapegawai['Other Salaries'])

total_salary={}
for baris in datapegawai['Total Salary']:
    if baris < 0:
        total_salary=abs(datapegawai['Total Salary'])

retirement={}
for baris in datap['Retirement']:
    if baris < 0:
        retirement=abs(datapegawai['Retirement'])

health_and_dental={}
for baris in datapegawai['Health and Dental']:
    if baris < 0:
        health_and_dental=abs(datapegawai['Health and Dental'])

other_benefits={}
for baris in datapegawai['Other Benefits']:
    if baris < 0:
        other_benefits=abs(datapegawai['Other Benefits'])

total_benefits={}
for baris in datapegawai['Total Benefits']:
    if baris < 0:
        total_benefits=abs(datapegawai['Total Benefits'])

total_compensation={}
for baris in datapegawai['Total Compensation']:
    if baris < 0:
        total_compensation=abs(datapegawai['Total Compensation'])

# %%
#Membentuk DataFrame Baru
datasuci=pd.DataFrame({'salaries': salaries,'overtime': overtime,'retirement': retirement,'other salaries':other_salaries, 'total salary':total_salary, 'health and dental':health_and_dental, 'other benefits':other_benefits,'total benefits':total_benefits,'total compensation':total_compensation})
datasuci.head()
# Out:
#    salaries  overtime  retirement  other salaries  total salary  \
# 0    674.28      0.00      130.91            5.76        680.04
# 1    674.28      0.00      130.91            5.76        680.04
# 2    674.28      0.00      130.91            5.76        680.04
# 3  47822.00      0.00     9986.92          264.00      48086.00
# 4  61089.35  39316.78    12385.79         6966.37     107372.50
#
#    health and dental  other benefits  total benefits  total compensation
# 0               0.00           53.86          184.77              864.81
# 1               0.00           53.86          184.77              864.81
# 2               0.00           53.86          184.77              864.81
# 3            6747.52         3898.79        20633.23            68719.23
# 4            6606.96         1816.03        20808.78           128181.28

# %%
bigdata.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
#   Union Code                           Union Job Family Code       Job Family  \
# 0        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# 1        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# ...

# %%
#Mengganti Data Number Salaries sampai Total Compensation dengan data yang sudah dibersihkan
databaru=datapegawai.drop('Salaries',axis=1)
databaru=databaru.drop('Overtime',axis=1)
databaru=databaru.drop('Other Salaries',axis=1)
databaru=databaru.drop('Total Salary',axis=1)
databaru=databaru.drop('Retirement',axis=1)
databaru=databaru.drop('Health and Dental',axis=1)
databaru=databaru.drop('Other Benefits',axis=1)
databaru=databaru.drop('Total Benefits',axis=1)
databaru=databaru.drop('Total Compensation',axis=1)
dataclean=pd.concat([databaru, datasuci], axis=1)
dataclean.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2028                        7
# 1  Calendar  2028                        1
# 2    Fiscal  2028                        1
# 3    Fiscal  2020                        3
# 4    Fiscal  2020                        1
#
#                          Organization Group Department Code Department  \
# 0             General City Responsibilities          229259        NaN
# 1                         Public Protection             CRT        NaN
# 2                         Public Protection             CRT        NaN
# 3  Human Welfare & Neighborhood Development             HSA        NaN
# 4                         Public Protection             POL        NaN
#
#   Union Code                           Union Job Family Code       Job Family  \
# 0        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# 1        792  Utd Pub EmpL790 SEIU-Crt Clrks            0000         Untitled
# ...

# %%
# Menghapus data yang terduplikasi
datasuci=dataclean.drop_duplicates(keep=False)

# %%
# mengkonversi dataframe ke file csv
bytes_to_write = datasuci.to_csv('datasuci.csv')
