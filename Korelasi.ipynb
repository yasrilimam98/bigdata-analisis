# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
datasuci = pd.read_csv('datasuci.csv')
datasuci.head()
# Out:
# /Users/devfx/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 Year Type  Year  Organization Group Code  \
# 0           0  Calendar  2028                        7
# 1           1  Calendar  2028                        1
# 2           2    Fiscal  2028                        1
# 3           7    Fiscal  2020                        2
# 4          37    Fiscal  2020                        2
#
#                         Organization Group Department Code Department  \
# 0            General City Responsibilities          229259        NaN
# 1                        Public Protection             CRT        NaN
# 2                        Public Protection             CRT        NaN
# 3  Public Works, Transportation & Commerce             DBI        NaN
# ...

# %%
#membuat ukuran gambar
plt.figure(figsize=(12,8))
plt.title('Kompensasi gaji pegawai di Kota fransisco (USD)', fontdict={'fontweight':'bold','fontsize':18})
plt.plot(datasuci.index, datasuci.salaries, 'b.-', label='Gaji pokok')
plt.plot(datasuci.index, datasuci.overtime, 'r.-', label='Gaji lembur')
plt.plot(datasuci.index, datasuci.retirement, 'g.-', label='Gaji pensiun')
plt.plot(datasuci.index, datasuci['other salaries'], 'm.-', label='Gaji tambahan')
plt.plot(datasuci.index, datasuci['other benefits'], 'c.-', label='Tunjang lain')
plt.plot(datasuci.index, datasuci['health and dental'], 'k.-', label='Tunjangan Kesehatan')

plt.xlabel('Tahun')
plt.ylabel('Dolar USD')

plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
datanumber = datasuci[['salaries','overtime','retirement','other salaries','total salary','health and dental','other benefits','total benefits','total compensation']]
Kolerasi=datanumber.corr()
print(Kolerasi)
# Out:
#                     salaries  overtime  retirement  other salaries  \
# salaries            1.000000  0.267580    0.948637        0.363467
# overtime            0.267580  1.000000    0.313138        0.375097
# retirement          0.948637  0.313138    1.000000        0.387016
# other salaries      0.363467  0.375097    0.387016        1.000000
# total salary        0.961977  0.497509    0.930993        0.520551
# health and dental   0.618370  0.272615    0.635236        0.185908
# other benefits      0.720181  0.073462    0.675191        0.083164
# total benefits      0.912425  0.292760    0.935959        0.300355
# total compensation  0.970891  0.454955    0.953532        0.474451
#
#                     total salary  health and dental  other benefits  \
# salaries                0.961977           0.618370        0.720181
# overtime                0.497509           0.272615        0.073462
# retirement              0.930993           0.635236        0.675191
# ...

# %%
plt.figure(figsize=(12,8))
plt.title('Gaji vs Kompensasi', fontdict={'fontweight':'bold','fontsize':18})
plt.scatter(datasuci['total salary'], datasuci['total compensation'])

plt.xlabel('Gaji')
plt.ylabel('Kompensasi')

plt.show()
